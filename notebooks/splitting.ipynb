# %%
import duckdb
from dotenv import load_dotenv
import os

# %%
load_dotenv()

con = duckdb.connect(":memory:")
con.sql("load postgres;")
con.sql(
    f"ATTACH 'dbname={os.getenv('DB_NAME')} user={os.getenv('DB_USER')} host={os.getenv('DB_HOST')} password={os.getenv('DB_PASSWORD')} port={os.getenv('DB_PORT')}' AS supabase (TYPE postgres, SCHEMA 'public');"
)

# %%
anime = con.sql("select * from supabase.anime;").df()

# %%
anime
# Out:
#       anime_id                               name  \
# 0        32281                     Kimi no Na wa.
# 1         5114   Fullmetal Alchemist: Brotherhood
# 2        28977                           Gintama°
# 3         9253                        Steins;Gate
# 4         9969                      Gintama&#039;
# ...        ...                                ...
# 7581     29633                             Kiseki
# 7582     19125                Mogura no Adventure
# 7583      9506  Prism Magical: Prism Generations!
# 7584      2262                     Sin: The Movie
# 7585       681             Tenbatsu Angel Rabbie☆
#
#                                                   genre     type episodes  \
# 0                  Drama, Romance, School, Supernatural    Movie        1
# 1     Action, Adventure, Drama, Fantasy, Magic, Mili...       TV       64
# 2     Action, Comedy, Historical, Parody, Samurai, S...       TV       51
# 3                                      Sci-Fi, Thriller       TV       24
# 4     Action, Comedy, Historical, Parody, Samurai, S...       TV       51
# ...                                                 ...      ...      ...
# 7581                                           Dementia    Movie        1
# 7582                                    Adventure, Kids  Special        1
# 7583                               Comedy, Ecchi, Magic      OVA        1
# 7584  Action, Horror, Police, Sci-Fi, Shounen, Super...      OVA        1
# 7585                              Comedy, Magic, Sci-Fi      OVA        1
#
#       rating  members
# 0       9.37   200630
# 1       9.26   793665
# 2       9.25   114262
# 3       9.17   673572
# 4       9.16   151266
# ...      ...      ...
# 7581    5.27      130
# 7582    5.27      213
# 7583    5.27     1733
# 7584    5.27     3117
# 7585    5.27     1192
#
# [7586 rows x 7 columns]

# %%
anime["genre"]
# Out:
# 0                    Drama, Romance, School, Supernatural
# 1       Action, Adventure, Drama, Fantasy, Magic, Mili...
# 2       Action, Comedy, Historical, Parody, Samurai, S...
# 3                                        Sci-Fi, Thriller
# 4       Action, Comedy, Historical, Parody, Samurai, S...
#                               ...
# 7581                                             Dementia
# 7582                                      Adventure, Kids
# 7583                                 Comedy, Ecchi, Magic
# 7584    Action, Horror, Police, Sci-Fi, Shounen, Super...
# 7585                                Comedy, Magic, Sci-Fi
# Name: genre, Length: 7586, dtype: object

# %%
anime["genre"] = anime["genre"].str.strip()
anime["genre"] = anime["genre"].str.lower()
anime["genre"]
# Out:
# 0                    drama, romance, school, supernatural
# 1       action, adventure, drama, fantasy, magic, mili...
# 2       action, comedy, historical, parody, samurai, s...
# 3                                        sci-fi, thriller
# 4       action, comedy, historical, parody, samurai, s...
#                               ...
# 7581                                             dementia
# 7582                                      adventure, kids
# 7583                                 comedy, ecchi, magic
# 7584    action, horror, police, sci-fi, shounen, super...
# 7585                                comedy, magic, sci-fi
# Name: genre, Length: 7586, dtype: object

# %%
anime["genre"].str.split(",").explode("")
# Out:
# 0               drama
# 0             romance
# 0              school
# 0        supernatural
# 1              action
#             ...
# 7584          shounen
# 7584     supernatural
# 7585           comedy
# 7585            magic
# 7585           sci-fi
# Name: genre, Length: 26684, dtype: object

# %%
genres = anime["genre"].str.split(",").explode("")
genres
# Out:
# 0               drama
# 0             romance
# 0              school
# 0        supernatural
# 1              action
#             ...
# 7584          shounen
# 7584     supernatural
# 7585           comedy
# 7585            magic
# 7585           sci-fi
# Name: genre, Length: 26684, dtype: object

# %%
genres.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 26684 entries, 0 to 7585
# Series name: genre
# Non-Null Count  Dtype
# --------------  -----
# 26684 non-null  object
# dtypes: object(1)
# memory usage: 416.9+ KB

# %%
genres = genres.to_frame()
genres
# Out:
#               genre
# 0             drama
# 0           romance
# 0            school
# 0      supernatural
# 1            action
# ...             ...
# 7584        shounen
# 7584   supernatural
# 7585         comedy
# 7585          magic
# 7585         sci-fi
#
# [26684 rows x 1 columns]

# %%
genres["genre"] = genres["genre"].str.strip()
genres["genre"] = genres["genre"].str.lower()

# %%
genres
# Out:
#              genre
# 0            drama
# 0          romance
# 0           school
# 0     supernatural
# 1           action
# ...            ...
# 7584       shounen
# 7584  supernatural
# 7585        comedy
# 7585         magic
# 7585        sci-fi
#
# [26684 rows x 1 columns]

# %%
genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26684 entries, 0 to 7585
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   genre   26684 non-null  object
# dtypes: object(1)
# memory usage: 416.9+ KB

# %%
genres_gb = genres.groupby("genre")["genre"].count().reset_index(name="count")
genres_gb
# Out:
#             genre  count
# 0                     10
# 1          action   2327
# 2       adventure   1804
# 3            cars     48
# 4          comedy   3383
# 5        dementia     67
# 6          demons    194
# 7           drama   1512
# 8           ecchi    571
# 9         fantasy   1647
# 10           game    147
# 11          harem    277
# 12     historical    475
# 13         horror    257
# 14          josei     50
# 15           kids    526
# 16          magic    639
# 17   martial arts    209
# 18          mecha    811
# 19       military    376
# 20          music    533
# 21        mystery    442
# 22         parody    281
# 23         police    165
# 24  psychological    192
# 25        romance   1282
# 26        samurai    110
# 27         school   1007
# 28         sci-fi   1732
# 29         seinen    454
# 30         shoujo    528
# 31      shoujo ai     51
# 32        shounen   1526
# 33     shounen ai     59
# 34  slice of life    895
# 35          space    306
# 36         sports    391
# 37    super power    383
# 38   supernatural    849
# 39       thriller     79
# 40        vampire     89

# %%
genres_gb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   genre   41 non-null     object
#  1   count   41 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 788.0+ bytes

# %%
genres_gb["genre"].unique()

# %%
types = anime.groupby("type")["type"].count().reset_index(name="count")
types
# Out:
#       type  count
# 0    Movie   1296
# 1    Music    295
# 2      ONA    324
# 3      OVA   1438
# 4  Special   1294
# 5       TV   2939
